# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
new_samples_unconditional = np.load('samples_unconditional.npy')
new_samples_conditional = np.load('samples_conditional.npy')
gt = np.load('gt.npy')

# %%
plt.imshow(new_samples_unconditional[-1, :, :, 3], interpolation=None)
plt.show()

# %%
plt.imshow(gt[0, :, :, 3], interpolation=None)
plt.show()
